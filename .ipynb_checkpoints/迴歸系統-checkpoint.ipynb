# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.linspace(0,5,50)
y=1.2*x+0.8
plt.scatter(x,y)

# %%
y=1.2*x+0.8+0.5*np.random.randn(50)

# %%
plt.scatter(x,y)
plt.plot(x,1.2*x+0.8,'b')

# %%
from sklearn.linear_model import  LinearRegression

# %%
regr=LinearRegression()

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
X=x.reshape(len(x),1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y=regr.predict(X)

# %%
regr.predict([[1.3]])
# Out:
# array([2.45416204])

# %%
plt.scatter(x,y)
plt.plot(x,Y,'r')
plt.plot(x,1.2*x+0.8,'b')

# %%
x=np.linspace(0,5,200)
y=1.2*x+0.8+0.5*np.random.randn(200)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
X=x.reshape(len(x),1)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=9487)

# %%
plt.scatter(x_train,y_train)

# %%
plt.scatter(x_test,y_test)

# %%
regr=LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_pred=regr.predict(x_test)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,Y_pred,'r')
plt.plot(x,1.2*x+0.8,'g')

# %%
# Out:
# array([4.55395509, 1.96961156, 4.03708639, 0.93587415, 1.78718731,
#        5.16203592, 4.49314701, 1.69597519, 3.76345001, 2.42567218,
#        3.4594096 , 2.12163177, 3.36819747, 4.94920763, 2.82092472,
#        5.28365209, 6.19577334, 5.31405613, 4.85799551, 2.54728835,
#        2.33446006, 3.88506618, 4.31072276, 4.7059753 , 2.48648027,
#        4.3411268 , 1.66557114, 3.82425809, 2.3648641 , 4.21951063,
#        2.27365197, 0.9054701 , 3.18577322, 3.73304597, 2.18243985,
#        4.43233893, 3.91547022, 5.70930867, 6.56062184, 4.76678338,
#        5.952541  , 6.43900567, 2.79052068, 6.04375313, 1.87839943,
#        4.46274297, 6.53021779, 1.33112669, 3.12496514, 5.92213696,
#        3.0945611 , 4.73637934, 5.61809655, 5.73971271, 1.84799539,
#        1.54395498, 6.3173895 , 6.80385417, 5.86132888, 4.79718742])
